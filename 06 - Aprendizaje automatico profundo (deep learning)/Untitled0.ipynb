# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %ls gdrive/MyDrive/'Colab Notebooks'/06-Deep-Learning/
# Out:
# Untitled0.ipynb

# %%
# %cd gdrive/MyDrive/'Colab Notebooks'/06-Deep-Learning/
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/06-Deep-Learning

# %%
! git clone https://github.com/DiploDatos/AprendizajeProfundo.git
# Out:
# Cloning into 'AprendizajeProfundo'...
# remote: Enumerating objects: 369, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 369 (delta 83), reused 79 (delta 73), pack-reused 269
# Receiving objects: 100% (369/369), 4.92 MiB | 668.00 KiB/s, done.
# Resolving deltas: 100% (183/183), done.

# %%
! git pull
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
