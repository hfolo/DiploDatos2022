# %% [markdown]
# **Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones**
#
# **Exploración y Curación de Datos**
#
# *Edición 2022*
#
# ----
#
# # Trabajo práctico entregable - parte 1
#
# En esta notebook, vamos a cargar el conjunto de datos de [la compentencia Kaggle](https://www.kaggle.com/dansbecker/melbourne-housing-snapshot) sobre estimación de precios de ventas de propiedades en Melbourne, Australia.
#
# Utilizaremos el conjunto de datos reducido producido por [DanB](https://www.kaggle.com/dansbecker). Hemos subido una copia a un servidor de la Universidad Nacional de Córdoba para facilitar su acceso remoto.

# %% [markdown]
# Autores:
# - Gustavo Jara
# - Hugo Folonier
# - Candelaria Arpajou

# %%
import matplotlib.pyplot as plt
import numpy
import pandas
import seaborn
seaborn.set_context('talk')
import missingno as msno

# %%
# La instalación de decouple daba error, por lo que tuvimos que desinstalarla e instalarla nuevamente como python-decouple

#pip uninstall decouple
# !pip install python-decouple
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-decouple
#   Downloading python_decouple-3.6-py3-none-any.whl (9.9 kB)
# Installing collected packages: python-decouple
# Successfully installed python-decouple-3.6

# %%
#from decouple import config

# Collecting python-decouple
#  Downloading python_decouple-3.6-py3-none-any.whl (9.9 kB)
# Installing collected packages: python-decouple
# Successfully installed python-decouple-3.6

from sqlalchemy import create_engine, text

# %%
# La versión más nueva es 5.5.0, por lo que por las dudas instalamos la versión requerida:
# !pip install plotly==4.14.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting plotly==4.14.3
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
#      |████████████████████████████████| 13.2 MB 4.5 MB/s
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly==4.14.3) (1.15.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11447 sha256=742335cced832c22920b6c1ec9642d18a25360ee013809bc8cb08defd9b2501a
#   Stored in directory: /root/.cache/pip/wheels/f9/8d/8d/f6af3f7f9eea3553bc2fe6d53e4b287dad18b06a861ac56ddf
# Successfully built retrying
# Installing collected packages: retrying, plotly
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# Successfully installed plotly-4.14.3 retrying-1.3.3

# %%
import plotly
plotly.__version__
# Make sure it's 4.14.3
# Out:
# '4.14.3'

# %%
# Creación DF con la información de Ventas de Melbourne
melb_df = pandas.read_csv('https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv')
melb_df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0
# 1        Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0
# 2        Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0
# 3        Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0
# 4        Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0
# ...         ...         ...       ...       ...  ...       ...  ...       ...
# 13575     Barry  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  Williams  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577     Raine  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578   Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579   Village  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0               NaN        NaN        Yarra -37.79960   144.99840
# 1              79.0     1900.0        Yarra -37.80790   144.99340
# 2             150.0     1900.0        Yarra -37.80930   144.99440
# 3               NaN        NaN        Yarra -37.79690   144.99690
# 4             142.0     2014.0        Yarra -37.80720   144.99410
# ...             ...        ...          ...       ...         ...
# 13575           NaN     1981.0          NaN -37.90562   145.16761
# 13576         133.0     1995.0          NaN -37.85927   144.87904
# 13577           NaN     1997.0          NaN -37.85274   144.88738
# 13578         157.0     1920.0          NaN -37.85908   144.89299
# 13579         112.0     1920.0          NaN -37.81188   144.88449
#
#                        Regionname Propertycount
# 0           Northern Metropolitan        4019.0
# 1           Northern Metropolitan        4019.0
# 2           Northern Metropolitan        4019.0
# 3           Northern Metropolitan        4019.0
# 4           Northern Metropolitan        4019.0
# ...                           ...           ...
# 13575  South-Eastern Metropolitan        7392.0
# 13576        Western Metropolitan        6380.0
# 13577        Western Metropolitan        6380.0
# 13578        Western Metropolitan        6380.0
# 13579        Western Metropolitan        6543.0
#
# [13580 rows x 21 columns]

# %%
# Creación DF con la información scrappeada de AirBnb
interesting_cols = ['description', 'neighborhood_overview', 'street', 'neighborhood', 'city', 'suburb', 'state', 'zipcode',
  'price', 'weekly_price', 'monthly_price', 'latitude', 'longitude']
airbnb_df = pandas.read_csv('https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/cleansed_listings_dec18.csv', usecols=interesting_cols)
airbnb_df[:3]
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (35) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                          description  \
# 0  House: Clean, New, Modern, Quite, Safe. 10Km f...
# 1  A large air conditioned room with queen spring...
# 2  RIGHT IN THE HEART OF ST KILDA! It doesn't get...
#
#                                neighborhood_overview  \
# 0       Very safe! Family oriented. Older age group.
# 1  This hip area is a crossroads between two grea...
# 2  A stay at our apartment means you can enjoy so...
#
#                            street  neighborhood          city          suburb  \
# 0         Bulleen, VIC, Australia  Balwyn North    Manningham         Bulleen
# 1  Brunswick East, VIC, Australia     Brunswick      Moreland  Brunswick East
# 2        St Kilda, VIC, Australia      St Kilda  Port Phillip        St Kilda
#
#   state zipcode   latitude   longitude  price  weekly_price  monthly_price
# 0   VIC    3105 -37.772684  145.092133     60           NaN            NaN
# 1   VIC    3057 -37.766505  144.980736     35         200.0          803.0
# 2   VIC    3182 -37.859755  144.977369    159        1253.0         4452.0

# %% [markdown]
# ## Ejercicio 1 SQL:
#
# 1. Crear una base de datos en SQLite utilizando la libreria [SQLalchemy](https://stackoverflow.com/questions/2268050/execute-sql-from-file-in-sqlalchemy).
# https://docs.sqlalchemy.org/en/14/core/engines.html#sqlite
#
# 2. Ingestar los datos provistos en 'https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/melb_data.csv' en una tabla y el dataset generado en clase con datos de airbnb y sus precios por codigo postal en otra.
#
# 3. Implementar consultas en SQL que respondan con la siguiente información:
#
#     - cantidad de registros totales por ciudad.
#     - cantidad de registros totales por barrio y ciudad.
#
# 4. Combinar los datasets de ambas tablas ingestadas utilizando el comando JOIN de SQL  para obtener un resultado similar a lo realizado con Pandas en clase.

# %% [markdown]
# ### Creación de Base de Datos

# %%
engine = create_engine('sqlite:///mb_db', echo=True)
connection = engine.connect()

# %% [markdown]
# ### Ingestión de Datos

# %% [markdown]
# #### Tabla melbourne

# %%
msno.matrix(melb_df)

# %%
# Completar CouncilArea con las variables Latitud y Longitud
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="tp1")

melb_completed_df = melb_df.copy()
empty_councilarea = melb_completed_df[melb_completed_df.CouncilArea.isnull()==True]
# TODO? Sería mas eficiente guardar solo el indice y no todo el dataframe

for ind in empty_councilarea.index:
  coordenadas = str(melb_completed_df['Lattitude'][ind]) + ", " + str(melb_completed_df['Longtitude'][ind])
  councilArea = geolocator.reverse(coordenadas) # Llamo a la API para obtener los datos sobre la dirección a partir de las coordenadas geográficas
  try:
    if int(melb_completed_df['Postcode'][ind]) == int(councilArea.raw['address']['postcode']):
      melb_completed_df.loc[[ind],['CouncilArea']] = councilArea.raw['address']['suburb']
  except:
    print(councilArea.raw)

msno.matrix(melb_completed_df)
# Finalmente ahora si cortamos el DataFrame con los CouncilArea que no pudimos recuperar a partir de las coordenadas, por no coincidir con el postcode

melb_completed_df = melb_completed_df[melb_completed_df.CouncilArea.isnull()==False]

# Para bajar el archivo ya corregido
#melb_completed_df.to_csv('melb_completed_df.csv', index=None)
#from google.colab import files
#files.download('melb_completed_df.csv')
# Out:
# {'place_id': 109544776, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 31241265, 'lat': '-37.856417979569926', 'lon': '144.70655083061416', 'display_name': 'Jasmine Close, Kingston Gardens, Melbourne, City of Wyndham, Victoria, 3029, Australia', 'address': {'road': 'Jasmine Close', 'residential': 'Kingston Gardens', 'city': 'Melbourne', 'municipality': 'City of Wyndham', 'state': 'Victoria', 'postcode': '3029', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.8566077', '-37.8546584', '144.706496', '144.7067638']}
# {'place_id': 149624388, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 203684333, 'lat': '-37.68230726613276', 'lon': '144.56927039303906', 'display_name': 'Carina Drive, Melton, Melbourne, City of Melton, Victoria, 3337, Australia', 'address': {'road': 'Carina Drive', 'town': 'Melton', 'city': 'Melbourne', 'municipality': 'City of Melton', 'state': 'Victoria', 'postcode': '3337', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.6831793', '-37.6821562', '144.5684922', '144.5713836']}
# {'place_id': 149777434, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 203684335, 'lat': '-37.68133398341609', 'lon': '144.5710481946301', 'display_name': 'Perry Close, Melton, Melbourne, City of Melton, Victoria, 3337, Australia', 'address': {'road': 'Perry Close', 'town': 'Melton', 'city': 'Melbourne', 'municipality': 'City of Melton', 'state': 'Victoria', 'postcode': '3337', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.6814511', '-37.6812683', '144.5688319', '144.5720881']}
# {'place_id': 141999347, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172635188, 'lat': '-37.57025655047965', 'lon': '144.711475064733', 'display_name': 'Brett Court, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Brett Court', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5721294', '-37.5693305', '144.7111261', '144.711635']}
# {'place_id': 142126105, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172635168, 'lat': '-37.56274047362992', 'lon': '144.7118151901874', 'display_name': 'Lister Crescent, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Lister Crescent', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5631266', '-37.5609809', '144.7102471', '144.7125632']}
# {'place_id': 142007034, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172480939, 'lat': '-37.5817615', 'lon': '144.7105563', 'display_name': 'Oxley Street, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Oxley Street', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5817615', '-37.5800156', '144.7105563', '144.7141835']}
# {'place_id': 142299031, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 173553348, 'lat': '-37.58303752904323', 'lon': '144.73669340164471', 'display_name': 'Vaughan Street, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Vaughan Street', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5852125', '-37.5818179', '144.7345726', '144.7379145']}
# {'place_id': 166290950, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 261210632, 'lat': '-37.50635321775911', 'lon': '144.58135254969906', 'display_name': 'Morilla Court, Gisborne, Shire of Macedon Ranges, Victoria, 3437, Australia', 'address': {'road': 'Morilla Court', 'town': 'Gisborne', 'municipality': 'Shire of Macedon Ranges', 'state': 'Victoria', 'postcode': '3437', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5074912', '-37.5063351', '144.5807198', '144.581516']}
# {'place_id': 143307370, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 177509804, 'lat': '-37.4968219858947', 'lon': '144.62639242371733', 'display_name': 'Panorama Drive, Gisborne, Shire of Macedon Ranges, Victoria, 3437, Australia', 'address': {'road': 'Panorama Drive', 'town': 'Gisborne', 'municipality': 'Shire of Macedon Ranges', 'state': 'Victoria', 'postcode': '3437', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5007713', '-37.4926996', '144.6206658', '144.627178']}
# {'place_id': 101228930, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 14889729, 'lat': '-37.83495363572494', 'lon': '145.23239067644334', 'display_name': 'Portsmouth Street, Heathmont, Melbourne, City of Maroondah, Victoria, VIC 3134, Australia', 'address': {'road': 'Portsmouth Street', 'suburb': 'Heathmont', 'city': 'Melbourne', 'municipality': 'City of Maroondah', 'state': 'Victoria', 'postcode': 'VIC 3134', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.8349635', '-37.8349476', '145.2302961', '145.2336723']}
# {'place_id': 102254153, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 14890230, 'lat': '-37.831269', 'lon': '145.2283363', 'display_name': 'Westmore Drive, Heathmont, Melbourne, City of Maroondah, Victoria, VIC 3134, Australia', 'address': {'road': 'Westmore Drive', 'suburb': 'Heathmont', 'city': 'Melbourne', 'municipality': 'City of Maroondah', 'state': 'Victoria', 'postcode': 'VIC 3134', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.8314582', '-37.83119', '145.2283363', '145.2313939']}
# {'place_id': 107876322, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 27188506, 'lat': '-37.57289948530392', 'lon': '144.70032916902318', 'display_name': 'Kemp Place, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Kemp Place', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5731955', '-37.5728784', '144.7000106', '144.7003397']}
# {'place_id': 142135151, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172493627, 'lat': '-37.58559329027567', 'lon': '144.71563931540143', 'display_name': 'Carlson Street, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Carlson Street', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5862484', '-37.5854004', '144.7155368', '144.7156695']}
# {'place_id': 223771326, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 594279349, 'lat': '-37.57369434954568', 'lon': '144.7185834105336', 'display_name': 'Perceval Street, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Perceval Street', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5750024', '-37.5733739', '144.7183885', '144.7186361']}
# {'place_id': 143346445, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 177402828, 'lat': '-37.50720624855328', 'lon': '144.5866832227017', 'display_name': 'Wyralla Crescent, Gisborne, Shire of Macedon Ranges, Victoria, 3437, Australia', 'address': {'road': 'Wyralla Crescent', 'town': 'Gisborne', 'municipality': 'Shire of Macedon Ranges', 'state': 'Victoria', 'postcode': '3437', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5073656', '-37.5040799', '144.5814782', '144.5877738']}
# {'place_id': 115643587, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 55297900, 'lat': '-37.8298335268334', 'lon': '145.2098018039474', 'display_name': 'Churinga Avenue, Mitcham, Melbourne, City of Whitehorse, Victoria, VIC 3134, Australia', 'address': {'road': 'Churinga Avenue', 'suburb': 'Mitcham', 'city': 'Melbourne', 'municipality': 'City of Whitehorse', 'state': 'Victoria', 'postcode': 'VIC 3134', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.8298997', '-37.829753', '145.2087818', '145.2133525']}
# {'place_id': 142119441, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172795578, 'lat': '-37.57644504177988', 'lon': '144.747664036431', 'display_name': 'Briarwood Court, Goonawarra, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Briarwood Court', 'neighbourhood': 'Goonawarra', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5764514', '-37.5764131', '144.7471449', '144.7476946']}
# {'place_id': 194875343, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 406746370, 'lat': '-37.57134356255813', 'lon': '144.7232111097755', 'display_name': 'Riddell Road, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Riddell Road', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5741866', '-37.5705617', '144.722284', '144.7262421']}
# {'place_id': 141159483, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 168812412, 'lat': '-37.58895675561785', 'lon': '144.7019848145151', 'display_name': 'Whitty Lane, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Whitty Lane', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5890151', '-37.5888941', '144.7017592', '144.702195']}
# {'place_id': 113213276, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 44355842, 'lat': '-37.40870766073078', 'lon': '144.97747114607193', 'display_name': 'Danaher Avenue, Wallan, Shire of Mitchell, Victoria, 3756, Australia', 'address': {'road': 'Danaher Avenue', 'town': 'Wallan', 'municipality': 'Shire of Mitchell', 'state': 'Victoria', 'postcode': '3756', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.4095598', '-37.4070373', '144.9755651', '144.9775714']}
# {'place_id': 101479329, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 14890137, 'lat': '-37.82719069421037', 'lon': '145.2291407995457', 'display_name': 'Lee Court, Heathmont, Melbourne, City of Maroondah, Victoria, VIC 3134, Australia', 'address': {'road': 'Lee Court', 'suburb': 'Heathmont', 'city': 'Melbourne', 'municipality': 'City of Maroondah', 'state': 'Victoria', 'postcode': 'VIC 3134', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.8274041', '-37.827188', '145.2281152', '145.2295475']}
# {'place_id': 142059856, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172784228, 'lat': '-37.56265588332603', 'lon': '144.7303715662586', 'display_name': 'Curtin Drive, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Curtin Drive', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5629888', '-37.5626096', '144.7294356', '144.7330615']}
# {'place_id': 142133930, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172480917, 'lat': '-37.584765888913616', 'lon': '144.71524243280896', 'display_name': 'Plante Court, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Plante Court', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5853499', '-37.5834533', '144.7151584', '144.7154313']}
# {'place_id': 109300918, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 30108110, 'lat': '-37.836716580536375', 'lon': '145.21269134779385', 'display_name': 'Centre Road, Vermont, Melbourne, City of Whitehorse, Victoria, VIC 3134, Australia', 'address': {'road': 'Centre Road', 'suburb': 'Vermont', 'city': 'Melbourne', 'municipality': 'City of Whitehorse', 'state': 'Victoria', 'postcode': 'VIC 3134', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.836722', '-37.8367034', '145.2110959', '145.2132652']}
# {'place_id': 109190629, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 31249487, 'lat': '-37.85164418362018', 'lon': '144.70814528502703', 'display_name': 'Albion Court, Bengrove, Melbourne, City of Wyndham, Victoria, 3029, Australia', 'address': {'road': 'Albion Court', 'residential': 'Bengrove', 'city': 'Melbourne', 'municipality': 'City of Wyndham', 'state': 'Victoria', 'postcode': '3029', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.8518016', '-37.8512307', '144.7078967', '144.7083004']}
# {'place_id': 109162608, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 31227503, 'lat': '-37.868537867799134', 'lon': '144.69357332424738', 'display_name': 'Davie Crescent, Mossfiel, Melbourne, City of Wyndham, Victoria, 3029, Australia', 'address': {'road': 'Davie Crescent', 'residential': 'Mossfiel', 'city': 'Melbourne', 'municipality': 'City of Wyndham', 'state': 'Victoria', 'postcode': '3029', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.8691861', '-37.8684114', '144.6924141', '144.6945002']}
# {'place_id': 108378007, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 29312467, 'lat': '-37.68751859226861', 'lon': '144.56870898878157', 'display_name': 'Rosina Drive, Melton, Melbourne, City of Melton, Victoria, 3337, Australia', 'address': {'road': 'Rosina Drive', 'town': 'Melton', 'city': 'Melbourne', 'municipality': 'City of Melton', 'state': 'Victoria', 'postcode': '3337', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.6879063', '-37.6852567', '144.5686738', '144.5703655']}
# {'place_id': 239598083, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 698157524, 'lat': '-37.45409791720311', 'lon': '144.5886168035233', 'display_name': 'Hamilton Road, New Gisborne, Shire of Macedon Ranges, Victoria, 3438, Australia', 'address': {'road': 'Hamilton Road', 'hamlet': 'New Gisborne', 'city_district': 'New Gisborne', 'municipality': 'Shire of Macedon Ranges', 'state': 'Victoria', 'postcode': '3438', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.4553468', '-37.4531035', '144.5807497', '144.5996361']}
# {'place_id': 118532780, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 74112394, 'lat': '-37.58805109823802', 'lon': '144.73718514138866', 'display_name': 'Harker Street, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Harker Street', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5897718', '-37.5858641', '144.7320457', '144.7391623']}
# {'place_id': 277966214, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 957403061, 'lat': '-37.579430599999995', 'lon': '144.72306859572728', 'display_name': 'Gap Road Medical Centre, Ligar Street, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'building': 'Gap Road Medical Centre', 'road': 'Ligar Street', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5795751', '-37.57934', '144.7228185', '144.7231676']}
# {'place_id': 143131223, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 173556396, 'lat': '-37.591005734212', 'lon': '144.72581942899413', 'display_name': 'Paperbark Avenue, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Paperbark Avenue', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5910517', '-37.5909748', '144.7245661', '144.7264459']}
# {'place_id': 142001284, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172464879, 'lat': '-37.58472431294678', 'lon': '144.70003521736595', 'display_name': 'Ponsford Place, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Ponsford Place', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5847445', '-37.5846995', '144.6996259', '144.7002282']}
# {'place_id': 107273029, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 27055669, 'lat': '-37.572438577383785', 'lon': '144.7042995845307', 'display_name': 'Richardson Avenue, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Richardson Avenue', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.57244', '-37.5715326', '144.7029017', '144.7048998']}
# {'place_id': 109222666, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 31249122, 'lat': '-37.84973484871951', 'lon': '144.67155078611427', 'display_name': 'Abbotswood Drive, Oakwood, Melbourne, City of Wyndham, Victoria, 3029, Australia', 'address': {'road': 'Abbotswood Drive', 'residential': 'Oakwood', 'city': 'Melbourne', 'municipality': 'City of Wyndham', 'state': 'Victoria', 'postcode': '3029', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.849769', '-37.8491253', '144.670758', '144.6743812']}
# {'place_id': 130848942, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 128086699, 'lat': '-37.67845696725057', 'lon': '144.593107575873', 'display_name': 'Yuille Street, Melton, Melbourne, City of Melton, Victoria, 3337, Australia', 'address': {'road': 'Yuille Street', 'town': 'Melton', 'city': 'Melbourne', 'municipality': 'City of Melton', 'state': 'Victoria', 'postcode': '3337', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.6803765', '-37.677011', '144.5897616', '144.5956278']}
# {'place_id': 139726551, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 161036340, 'lat': '-37.82359776875508', 'lon': '145.2087509570368', 'display_name': 'Purches Street, Mitcham, Melbourne, City of Whitehorse, Victoria, VIC 3134, Australia', 'address': {'road': 'Purches Street', 'suburb': 'Mitcham', 'city': 'Melbourne', 'municipality': 'City of Whitehorse', 'state': 'Victoria', 'postcode': 'VIC 3134', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.8244237', '-37.8189209', '145.208656', '145.2088653']}
# {'place_id': 142797661, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 173553241, 'lat': '-37.58164522507742', 'lon': '144.73161172226406', 'display_name': 'Barkly Street, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Barkly Street', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5819236', '-37.5812452', '144.7313716', '144.7319018']}
# {'place_id': 142017977, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172635169, 'lat': '-37.55992083524583', 'lon': '144.70898325153553', 'display_name': 'Fullbrook Drive, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Fullbrook Drive', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5631882', '-37.5589445', '144.7050706', '144.7097412']}
# {'place_id': 142319266, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 172637972, 'lat': '-37.577955187444566', 'lon': '144.72362700975054', 'display_name': 'Ligar Street, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Ligar Street', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5797368', '-37.5775304', '144.7223655', '144.7239506']}
# {'place_id': 224037705, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 594674519, 'lat': '-37.565446873885385', 'lon': '144.71215706741958', 'display_name': 'Stewarts Lane, Sunbury, Melbourne, City of Hume, Victoria, 3429, Australia', 'address': {'road': 'Stewarts Lane', 'town': 'Sunbury', 'city': 'Melbourne', 'municipality': 'City of Hume', 'state': 'Victoria', 'postcode': '3429', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.5665147', '-37.564702', '144.7117859', '144.7135763']}
# {'place_id': 145802646, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright', 'osm_type': 'way', 'osm_id': 184857781, 'lat': '-37.86758671804011', 'lon': '144.65607707441072', 'display_name': 'McMahon Crescent, Riverview Park, Melbourne, City of Wyndham, Victoria, 3029, Australia', 'address': {'road': 'McMahon Crescent', 'residential': 'Riverview Park', 'city': 'Melbourne', 'municipality': 'City of Wyndham', 'state': 'Victoria', 'postcode': '3029', 'country': 'Australia', 'country_code': 'au'}, 'boundingbox': ['-37.868923', '-37.8675206', '144.6552252', '144.6562958']}

# %%
# Carga del DF melbourne al motor SQL
if engine.dialect.has_table(connection, 'melbourne'): #engine.dialect.get_table_names(connection)
  connection.execute('DROP TABLE melbourne')
melb_completed_df.to_sql('melbourne',engine)
# Out:
# 2022-06-21 23:39:42,622 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("melbourne")
# 2022-06-21 23:39:42,625 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-21 23:39:42,629 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("melbourne")
# 2022-06-21 23:39:42,631 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-21 23:39:42,654 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("melbourne")
# 2022-06-21 23:39:42,656 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-21 23:39:42,658 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("melbourne")
# 2022-06-21 23:39:42,663 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-21 23:39:42,672 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-21 23:39:42,676 INFO sqlalchemy.engine.Engine
# CREATE TABLE melbourne (
# 	"index" BIGINT,
# 	"Suburb" TEXT,
# 	"Address" TEXT,
# 	"Rooms" BIGINT,
# 	"Type" TEXT,
# 	"Price" FLOAT,
# 	"Method" TEXT,
# 	"SellerG" TEXT,
# 	"Date" TEXT,
# 	"Distance" FLOAT,
# 	"Postcode" FLOAT,
# 	"Bedroom2" FLOAT,
# 	"Bathroom" FLOAT,
# 	"Car" FLOAT,
# 	"Landsize" FLOAT,
# 	"BuildingArea" FLOAT,
# 	"YearBuilt" FLOAT,
# 	"CouncilArea" TEXT,
# 	"Lattitude" FLOAT,
# 	"Longtitude" FLOAT,
# 	"Regionname" TEXT,
# 	"Propertycount" FLOAT
# )
#
#
# 2022-06-21 23:39:42,678 INFO sqlalchemy.engine.Engine [no key 0.00247s] ()
# 2022-06-21 23:39:42,696 INFO sqlalchemy.engine.Engine CREATE INDEX ix_melbourne_index ON melbourne ("index")
# 2022-06-21 23:39:42,697 INFO sqlalchemy.engine.Engine [no key 0.00137s] ()
# 2022-06-21 23:39:42,715 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-21 23:39:42,745 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-21 23:39:43,211 INFO sqlalchemy.engine.Engine INSERT INTO melbourne ("index", "Suburb", "Address", "Rooms", "Type", "Price", "Method", "SellerG", "Date", "Distance", "Postcode", "Bedroom2", "Bathroom", "Car", "Landsize", "BuildingArea", "YearBuilt", "CouncilArea", "Lattitude", "Longtitude", "Regionname", "Propertycount") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-06-21 23:39:43,214 INFO sqlalchemy.engine.Engine [generated in 0.42549s] ((0, 'Abbotsford', '85 Turner St', 2, 'h', 1480000.0, 'S', 'Biggin', '3/12/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 202.0, None, None, 'Yarra', -37.7996, 144.9984, 'Northern Metropolitan', 4019.0), (1, 'Abbotsford', '25 Bloomburg St', 2, 'h', 1035000.0, 'S', 'Biggin', '4/02/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 156.0, 79.0, 1900.0, 'Yarra', -37.8079, 144.9934, 'Northern Metropolitan', 4019.0), (2, 'Abbotsford', '5 Charles St', 3, 'h', 1465000.0, 'SP', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 0.0, 134.0, 150.0, 1900.0, 'Yarra', -37.8093, 144.9944, 'Northern Metropolitan', 4019.0), (3, 'Abbotsford', '40 Federation La', 3, 'h', 850000.0, 'PI', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 1.0, 94.0, None, None, 'Yarra', -37.7969, 144.9969, 'Northern Metropolitan', 4019.0), (4, 'Abbotsford', '55a Park St', 4, 'h', 1600000.0, 'VB', 'Nelson', '4/06/2016', 2.5, 3067.0, 3.0, 1.0, 2.0, 120.0, 142.0, 2014.0, 'Yarra', -37.8072, 144.9941, 'Northern Metropolitan', 4019.0), (5, 'Abbotsford', '129 Charles St', 2, 'h', 941000.0, 'S', 'Jellis', '7/05/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 181.0, None, None, 'Yarra', -37.8041, 144.9953, 'Northern Metropolitan', 4019.0), (6, 'Abbotsford', '124 Yarra St', 3, 'h', 1876000.0, 'S', 'Nelson', '7/05/2016', 2.5, 3067.0, 4.0, 2.0, 0.0, 245.0, 210.0, 1910.0, 'Yarra', -37.8024, 144.9993, 'Northern Metropolitan', 4019.0), (7, 'Abbotsford', '98 Charles St', 2, 'h', 1636000.0, 'S', 'Nelson', '8/10/2016', 2.5, 3067.0, 2.0, 1.0, 2.0, 256.0, 107.0, 1890.0, 'Yarra', -37.806, 144.9954, 'Northern Metropolitan', 4019.0)  ... displaying 10 of 13227 total bound parameter sets ...  (13578, 'Williamstown', '96 Verdon St', 4, 'h', 2500000.0, 'PI', 'Sweeney', '26/08/2017', 6.8, 3016.0, 4.0, 1.0, 5.0, 866.0, 157.0, 1920.0, 'Williamstown', -37.85908, 144.89299, 'Western Metropolitan', 6380.0), (13579, 'Yarraville', '6 Agnes St', 4, 'h', 1285000.0, 'SP', 'Village', '26/08/2017', 6.3, 3013.0, 4.0, 1.0, 1.0, 362.0, 112.0, 1920.0, 'Yarraville', -37.81188, 144.88449, 'Western Metropolitan', 6543.0))
# 2022-06-21 23:39:43,322 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# #### Tabla airbnb

# %%
# Conversión de la variable zipcode a formato numérico
airbnb_df['zipcode'] = pandas.to_numeric(airbnb_df['zipcode'], errors='coerce')

### Exploración de los campos suburb y neighborhood con valores NaN o NULL del DF AirBNB

# Conteo de filas con el campo neigborhood NULL
neighborhood_null = airbnb_df.neighborhood.isnull().value_counts()
print(neighborhood_null)

# Conteo de filas con el campo suburb NULL
suburb_null = airbnb_df.suburb.isnull().value_counts()
print(suburb_null)

# Observación gráfica de los valores NULL
msno.matrix(airbnb_df)

# Se decide eliminar los campos con muchos faltantes de datos
airbnb_df.drop(['neighborhood_overview', 'neighborhood'], axis = 1, inplace=True)

# Comprobación
msno.matrix(airbnb_df)

# Finalmente creo la tabla en la base de datos
if engine.dialect.has_table(connection, 'airbnb'):
  connection.execute('DROP TABLE airbnb')
airbnb_df.to_sql('airbnb', engine)
# Out:
# False    17082
# True      5813
# Name: neighborhood, dtype: int64
# False    22872
# True        23
# Name: suburb, dtype: int64
# 2022-06-21 23:39:43,724 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("airbnb")
# 2022-06-21 23:39:43,727 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-21 23:39:43,732 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("airbnb")
# 2022-06-21 23:39:43,735 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-21 23:39:43,764 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("airbnb")
# 2022-06-21 23:39:43,767 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-21 23:39:43,775 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("airbnb")
# 2022-06-21 23:39:43,780 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-06-21 23:39:43,790 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-21 23:39:43,796 INFO sqlalchemy.engine.Engine
# CREATE TABLE airbnb (
# 	"index" BIGINT,
# 	description TEXT,
# 	street TEXT,
# 	city TEXT,
# 	suburb TEXT,
# 	state TEXT,
# 	zipcode FLOAT,
# 	latitude FLOAT,
# 	longitude FLOAT,
# 	price BIGINT,
# 	weekly_price FLOAT,
# 	monthly_price FLOAT
# )
#
#
# 2022-06-21 23:39:43,799 INFO sqlalchemy.engine.Engine [no key 0.00216s] ()
# 2022-06-21 23:39:43,813 INFO sqlalchemy.engine.Engine CREATE INDEX ix_airbnb_index ON airbnb ("index")
# 2022-06-21 23:39:43,814 INFO sqlalchemy.engine.Engine [no key 0.00116s] ()
# 2022-06-21 23:39:43,828 INFO sqlalchemy.engine.Engine COMMIT
# 2022-06-21 23:39:43,853 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-06-21 23:39:44,341 INFO sqlalchemy.engine.Engine INSERT INTO airbnb ("index", description, street, city, suburb, state, zipcode, latitude, longitude, price, weekly_price, monthly_price) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2022-06-21 23:39:44,345 INFO sqlalchemy.engine.Engine [generated in 0.44796s] ((0, 'House: Clean, New, Modern, Quite, Safe. 10Km from the City. Golf course, Tennis courts, bus stop & shops walking distance!! Rooms: Contains one queen ... (702 characters truncated) ... pproximately what your daily in and out hours might look like.  Note: There is a 5 year old fun loving dog who lives with us and is part of our famil', 'Bulleen, VIC, Australia', 'Manningham', 'Bulleen', 'VIC', 3105.0, -37.77268393, 145.0921328, 60, None, None), (1, "A large air conditioned room with queen spring mattress bed in a vintage apartment. Located right outside is a tram to the city just 19 minutes away. ... (702 characters truncated) ... ou east to Bundoora and west to Pacoevale. The Lygon Street tram line that goes past Melbourne University is 10 minutes walk west and Sydney Road and", 'Brunswick East, VIC, Australia', 'Moreland', 'Brunswick East', 'VIC', 3057.0, -37.76650512, 144.9807361, 35, 200.0, 803.0), (2, 'RIGHT IN THE HEART OF ST KILDA! It doesn\'t get more central than this! A fabulous north facing balcony apartment that offers right in the heart of t ... (703 characters truncated) ... system with iPod dock & DVD/CD player Selection of books, magazines, DVDs, CDs Glass framed console/desk with lamp Bedroom with queen bed, hotel qual', 'St Kilda, VIC, Australia', 'Port Phillip', 'St Kilda', 'VIC', 3182.0, -37.85975502, 144.9773691, 159, 1253.0, 4452.0), (3, "Comfortable, relaxed house, a home away from  home! This is a shared house, you will be sharing with me, plus the occasional other guest. Rooms are l ... (702 characters truncated) ... om, watch a movie, or TV, or relax in the back yard. Guest's privacy will be respected at all times. If you need information and tips on where to go,", 'Thornbury, VIC, Australia', 'Darebin', 'Thornbury', 'VIC', 3071.0, -37.75897072, 144.9892279, 50, 250.0, 920.0), (4, 'We offer comfortable accommodation in Inner Melbourne in Clement House, a two storey Victorian built in 1888. Large double bedroom with balcony, priv ... (660 characters truncated) ... n smoking house with an outside courtyard for smokers. The rate for guests that stay for a week are heavily discounted and therefore very attractive.', 'St Kilda East, VIC, Australia', 'Port Phillip', 'St Kilda East', 'VIC', 3183.0, -37.8645303, 144.9922379, 69, 400.0, 1900.0), (5, 'Please note: No booking will be accepted with children under the age of 13 years.  Accommodation is non smoking in apartment & on grounds.  All visit ... (702 characters truncated) ... om, toilet & living area with stereo and 32" LCD TV. A second bedroom (Autumn Room) is available with another Queen size bed for extra travelers if r', 'Berwick, VIC, Australia', 'Casey', 'Berwick', 'VIC', 3806.0, -38.05725414, 145.3393561, 98, 540.0, None), (6, 'Easy to travel from and to the Airport; quiet and safe neighbourhood; a spacious and sunny room; backyard for sun baking; a friendly host who are eas ... (702 characters truncated) ... ovided here for your comfort is in a two bedroom unit with 100sqm backyard(my green garden). This bedroom is airy and bright with big windows. Your r', 'Reservoir, VIC, Australia', 'Darebin', 'Reservoir', 'VIC', 3073.0, -37.69729418, 145.0008156, 50, 335.0, 1400.0), (7, "Comfortable and spacious room in an apartment close to the heart of Melbourne. High quality bedding and good sound proofing guarantees a good night's ... (702 characters truncated) ... take you right into the CBD, via Lonsdale Street and to Grattan Street, Melbourne University Tram 112 onto Collins Street Jolimont train station (10m", 'East Melbourne, VIC, Australia', 'Melbourne', 'East Melbourne', 'VIC', 3002.0, -37.81026723, 144.98592, 100, None, None)  ... displaying 10 of 22895 total bound parameter sets ...  (22893, "Immaculately presented and carefully maintained executive courtyard apartment, well spaced floor plan comprises a queen-sized bedroom with large mirr ... (702 characters trunc ...
# 2022-06-21 23:39:44,554 INFO sqlalchemy.engine.Engine COMMIT

# %% [markdown]
# ### Consultas de Exploración de Datos

# %%
### REQUERIMENTO ###

# 1) Cantidad de registros totales por ciudad.
# 2) Cantidad de registros totales por barrio y ciudad.

query1 = 'SELECT COUNT(1) as "Cantidad de Melbourne" FROM melbourne'
query2 = 'SELECT COUNT(1) as "Cantidad de AirBNB" FROM airbnb'
query3 = 'SELECT * FROM melbourne limit 10'
query4 = 'SELECT * FROM airbnb limit 10'
query5 = 'SELECT city, COUNT(1) as Cantidad FROM airbnb GROUP BY city ORDER BY count(1) DESC'
query6 = 'SELECT city, suburb, COUNT(1) as Cantidad FROM airbnb GROUP BY city, suburb HAVING count(1) > 100 ORDER BY count(1) DESC' # por ciudad y barrio
query7 = 'SELECT COUNT(1) as "Cantidad de Pares Ciudad-Barrio" FROM (SELECT DISTINCT city, suburb FROM airbnb GROUP BY city, suburb)' # por ciudad y barrio
query8 = 'SELECT CouncilArea, COUNT(1) FROM melbourne GROUP BY CouncilArea HAVING COUNT(1) > 100 ORDER BY COUNT(1) DESC'
query9 = 'SELECT CouncilArea, Suburb, COUNT(1) FROM melbourne GROUP BY CouncilArea, Suburb ORDER BY COUNT(1) DESC LIMIT 100' # por ciudad y barrio
query10 = 'SELECT COUNT(1) as "Cantidad de Pares Ciudad-Barrio" FROM (SELECT Suburb FROM melbourne GROUP BY Suburb HAVING COUNT(1) > 100 ORDER BY COUNT(1) DESC)' # por ciudad y barrio

queries = [query6, query7]
# queries = [query5, query6, query61, query7, query71, query72]

for query in queries:
  print(f'\n{query}')
  result = connection.execute(query)
  print(result.keys())
  for row in result:
    print(row)
# Out:
# SELECT city, suburb, COUNT(1) as Cantidad FROM airbnb GROUP BY city, suburb HAVING count(1) > 100 ORDER BY count(1) DESC
# 2022-06-21 23:39:45,675 INFO sqlalchemy.engine.Engine SELECT city, suburb, COUNT(1) as Cantidad FROM airbnb GROUP BY city, suburb HAVING count(1) > 100 ORDER BY count(1) DESC
# 2022-06-21 23:39:45,678 INFO sqlalchemy.engine.Engine [raw sql] ()
# RMKeyView(['city', 'suburb', 'Cantidad'])
# ('Melbourne', 'Melbourne', 3850)
# ('Melbourne', 'Southbank', 1190)
# ('Port Phillip', 'Saint Kilda', 802)
# ('Stonnington', 'South Yarra', 790)
# ('Melbourne', 'Docklands', 612)
# ('Yarra', 'Richmond', 570)
# ('Melbourne', 'Carlton', 531)
# ('Moreland', 'Brunswick', 434)
# ('Yarra', 'Fitzroy', 375)
# ('Melbourne', 'North Melbourne', 340)
# ('Port Phillip', 'Melbourne', 330)
# ('Port Phillip', 'Elwood', 325)
# ('Yarra', 'Collingwood', 295)
# ('Darebin', 'Northcote', 279)
# ('Port Phillip', 'South Melbourne', 278)
# ('Melbourne', 'West Melbourne', 263)
# ('Stonnington', 'Prahran', 261)
# ('Yarra', 'Abbotsford', 257)
# ('Port Phillip', 'Port Melbourne', 256)
# ('Yarra', 'Fitzroy North', 229)
# ('Port Phillip', 'St Kilda', 196)
# ('Wyndham', 'Point Cook', 191)
# ('Melbourne', 'East Melbourne', 184)
# ('Whitehorse', 'Box Hill', 182)
# ('Boroondara', 'Hawthorn', 181)
# ('Monash', 'Glen Waverley', 173)
# ('Moreland', 'Brunswick East', 171)
# ('Stonnington', 'Windsor', 169)
# ('Maribyrnong', 'Footscray', 166)
# ('Yarra Ranges', 'Healesville', 151)
# ('Darebin', 'Preston', 142)
# ('Port Phillip', 'Saint Kilda East', 139)
# ('Manningham', 'Doncaster', 132)
# ('Bayside', 'Brighton', 122)
# ('Stonnington', 'Toorak', 116)
# ('Glen Eira', 'Caulfield North', 114)
# ('Darebin', 'Thornbury', 113)
# ('Melbourne', 'Kensington', 112)
# ('Boroondara', 'Kew', 108)
# ('Moreland', 'Coburg', 108)
# ('Monash', 'Clayton', 107)
# ('Yarra', 'Carlton North', 103)
# ('Port Phillip', 'Balaclava', 102)
#
# SELECT COUNT(1) as "Cantidad de Pares Ciudad-Barrio" FROM (SELECT DISTINCT city, suburb FROM airbnb GROUP BY city, suburb)
# 2022-06-21 23:39:45,745 INFO sqlalchemy.engine.Engine SELECT COUNT(1) as "Cantidad de Pares Ciudad-Barrio" FROM (SELECT DISTINCT city, suburb FROM airbnb GROUP BY city, suburb)
# 2022-06-21 23:39:45,747 INFO sqlalchemy.engine.Engine [raw sql] ()
# RMKeyView(['Cantidad de Pares Ciudad-Barrio'])
# (692,)

# %% [markdown]
# ### Consultas Combinando las dos Fuentes
# Combinar los datasets de ambas tablas ingestadas utilizando el comando JOIN de SQL para obtener un resultado similar a lo realizado con Pandas en clase.

# %%
query11 = 'SELECT distinct CAST(Postcode as INT), count(1) as "Cantidad Melbourne"  FROM melbourne GROUP BY CAST(Postcode as INT) ORDER BY count(1) DESC LIMIT 20'
query12 = 'SELECT count(distinct CAST(Postcode as INT)) as "Cantidad Melbourne"  FROM melbourne'
query13 = 'SELECT distinct CAST(zipcode as INT), count(1) as "Cantidad AirBNB" FROM airbnb GROUP BY CAST(zipcode as INT) ORDER BY count(1) DESC LIMIT 20'
query14 = 'SELECT count(distinct CAST(zipcode as INT)) as "Cantidad AirBNB" FROM airbnb'
query15 = 'SELECT count(DISTINCT CAST(Postcode as INT)) as "C.P. en ambos" FROM melbourne WHERE CAST(Postcode as INT) in (SELECT DISTINCT CAST(zipcode as INT) FROM airbnb)'
query16 = 'SELECT count(DISTINCT CAST(zipcode as INT)) as "C.P. en ambos" FROM airbnb WHERE CAST(zipcode as INT) in (SELECT DISTINCT CAST(Postcode as INT) FROM melbourne)'
query17 = """
SELECT count(1) as 'Cantidad de ZipCodes que están en ambas tablas' 
FROM (SELECT DISTINCT CAST(Postcode as INT) as Code FROM melbourne) melbourne_grouped
JOIN (SELECT DISTINCT CAST(zipcode as INT) as Code FROM airbnb) airbnb_grouped
ON melbourne_grouped.Code = airbnb_grouped.Code
"""
# Agrego la condición HAVING > 10 en el agrupamiento para tomar sólo codigos con información relevante. Las coincidencias bajan a 138 Codigos
query18 = """
SELECT (melbourne_grouped.Melbourne_Qtty + airbnb_grouped.Airbnb_Qtty) as 'Total Registros', ' - ',melbourne_grouped.*, ' - ', airbnb_grouped.*
FROM (SELECT DISTINCT CAST(Postcode as INT) as Melbourne_Code, count(1) as Melbourne_Qtty, AVG(Price) as 'Melbourne_Avg_Price' FROM melbourne GROUP BY CAST(Postcode as INT) HAVING count(1) > 10) melbourne_grouped
JOIN (SELECT DISTINCT CAST(zipcode as INT) as Airbnb_Code, count(1) as Airbnb_Qtty, AVG(price) as 'Airbnb_Avg_Price' FROM airbnb GROUP BY CAST(zipcode as INT) HAVING count(1) > 10) airbnb_grouped
ON melbourne_grouped.Melbourne_Code = airbnb_grouped.Airbnb_Code
ORDER BY (melbourne_grouped.Melbourne_Qtty + airbnb_grouped.Airbnb_Qtty) DESC
"""
query19 = """
SELECT m.*, ' - ', a.*
FROM melbourne m
JOIN (SELECT DISTINCT CAST(zipcode as INT) as Airbnb_Code, count(1) as Airbnb_Qtty, AVG(price) as 'Airbnb_Avg_Price', AVG(weekly_price) as 'Airbnb_Avg_Weekly_Price', AVG(monthly_price) as 'Airbnb_Avg_Monthly_Price'
FROM airbnb GROUP BY CAST(zipcode as INT)) a
ON m.Postcode = a.Airbnb_Code
LIMIT 100
"""

queries = [query19]

for query in queries:
  print(f'\n{query}')
  result = connection.execute(query)
  print(result.keys())
  for row in result:
    print(row)
# Out:
# SELECT m.*, ' - ', a.*
# FROM melbourne m
# JOIN (SELECT DISTINCT CAST(zipcode as INT) as Airbnb_Code, count(1) as Airbnb_Qtty, AVG(price) as 'Airbnb_Avg_Price', AVG(weekly_price) as 'Airbnb_Avg_Weekly_Price', AVG(monthly_price) as 'Airbnb_Avg_Monthly_Price'
# FROM airbnb GROUP BY CAST(zipcode as INT)) a
# ON m.Postcode = a.Airbnb_Code
# LIMIT 100
#
# 2022-06-21 23:39:45,814 INFO sqlalchemy.engine.Engine
# SELECT m.*, ' - ', a.*
# FROM melbourne m
# JOIN (SELECT DISTINCT CAST(zipcode as INT) as Airbnb_Code, count(1) as Airbnb_Qtty, AVG(price) as 'Airbnb_Avg_Price', AVG(weekly_price) as 'Airbnb_Avg_Weekly_Price', AVG(monthly_price) as 'Airbnb_Avg_Monthly_Price'
# FROM airbnb GROUP BY CAST(zipcode as INT)) a
# ON m.Postcode = a.Airbnb_Code
# LIMIT 100
#
# 2022-06-21 23:39:45,815 INFO sqlalchemy.engine.Engine [raw sql] ()
# RMKeyView(['index', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname', 'Propertycount', "' - '", 'Airbnb_Code', 'Airbnb_Qtty', 'Airbnb_Avg_Price', 'Airbnb_Avg_Weekly_Price', 'Airbnb_Avg_Monthly_Price'])
# (0, 'Abbotsford', '85 Turner St', 2, 'h', 1480000.0, 'S', 'Biggin', '3/12/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 202.0, None, None, 'Yarra', -37.7996, 144.9984, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (1, 'Abbotsford', '25 Bloomburg St', 2, 'h', 1035000.0, 'S', 'Biggin', '4/02/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 156.0, 79.0, 1900.0, 'Yarra', -37.8079, 144.9934, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (2, 'Abbotsford', '5 Charles St', 3, 'h', 1465000.0, 'SP', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 0.0, 134.0, 150.0, 1900.0, 'Yarra', -37.8093, 144.9944, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (3, 'Abbotsford', '40 Federation La', 3, 'h', 850000.0, 'PI', 'Biggin', '4/03/2017', 2.5, 3067.0, 3.0, 2.0, 1.0, 94.0, None, None, 'Yarra', -37.7969, 144.9969, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (4, 'Abbotsford', '55a Park St', 4, 'h', 1600000.0, 'VB', 'Nelson', '4/06/2016', 2.5, 3067.0, 3.0, 1.0, 2.0, 120.0, 142.0, 2014.0, 'Yarra', -37.8072, 144.9941, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (5, 'Abbotsford', '129 Charles St', 2, 'h', 941000.0, 'S', 'Jellis', '7/05/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 181.0, None, None, 'Yarra', -37.8041, 144.9953, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (6, 'Abbotsford', '124 Yarra St', 3, 'h', 1876000.0, 'S', 'Nelson', '7/05/2016', 2.5, 3067.0, 4.0, 2.0, 0.0, 245.0, 210.0, 1910.0, 'Yarra', -37.8024, 144.9993, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (7, 'Abbotsford', '98 Charles St', 2, 'h', 1636000.0, 'S', 'Nelson', '8/10/2016', 2.5, 3067.0, 2.0, 1.0, 2.0, 256.0, 107.0, 1890.0, 'Yarra', -37.806, 144.9954, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (8, 'Abbotsford', '6/241 Nicholson St', 1, 'u', 300000.0, 'S', 'Biggin', '8/10/2016', 2.5, 3067.0, 1.0, 1.0, 1.0, 0.0, None, None, 'Yarra', -37.8008, 144.9973, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (9, 'Abbotsford', '10 Valiant St', 2, 'h', 1097000.0, 'S', 'Biggin', '8/10/2016', 2.5, 3067.0, 3.0, 1.0, 2.0, 220.0, 75.0, 1900.0, 'Yarra', -37.801, 144.9989, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (10, 'Abbotsford', '411/8 Grosvenor St', 2, 'u', 700000.0, 'VB', 'Jellis', '12/11/2016', 2.5, 3067.0, 2.0, 2.0, 1.0, 0.0, None, None, 'Yarra', -37.811, 145.0067, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (11, 'Abbotsford', '40 Nicholson St', 3, 'h', 1350000.0, 'VB', 'Nelson', '12/11/2016', 2.5, 3067.0, 3.0, 2.0, 2.0, 214.0, 190.0, 2005.0, 'Yarra', -37.8085, 144.9964, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (12, 'Abbotsford', '123/56 Nicholson St', 2, 'u', 750000.0, 'S', 'Biggin', '12/11/2016', 2.5, 3067.0, 2.0, 2.0, 1.0, 0.0, 94.0, 2009.0, 'Yarra', -37.8078, 144.9965, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (13, 'Abbotsford', '45 William St', 2, 'h', 1172500.0, 'S', 'Biggin', '13/08/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 195.0, None, None, 'Yarra', -37.8084, 144.9973, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (14, 'Abbotsford', '7/20 Abbotsford St', 1, 'u', 441000.0, 'SP', 'Greg', '14/05/2016', 2.5, 3067.0, 1.0, 1.0, 1.0, 0.0, None, None, 'Yarra', -37.8016, 144.9988, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (15, 'Abbotsford', '16 William St', 2, 'h', 1310000.0, 'S', 'Jellis', '15/10/2016', 2.5, 3067.0, 2.0, 1.0, 2.0, 238.0, 97.0, 1890.0, 'Yarra', -37.809, 144.9976, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (16, 'Abbotsford', '42 Henry St', 3, 'h', 1200000.0, 'S', 'Jellis', '16/07/2016', 2.5, 3067.0, 3.0, 2.0, 1.0, 113.0, 110.0, 1880.0, 'Yarra', -37.8056, 144.993, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (17, 'Abbotsford', '78 Yarra St', 3, 'h', 1176500.0, 'S', 'LITTLE', '16/07/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 138.0, 105.0, 1890.0, 'Yarra', -37.8021, 144.9965, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (18, 'Abbotsford', '196 Nicholson St', 3, 'h', 955000.0, 'S', 'Collins', '17/09/2016', 2.5, 3067.0, 3.0, 1.0, 0.0, 183.0, None, None, 'Yarra', -37.8022, 144.9975, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (19, 'Abbotsford', '42 Valiant St', 2, 'h', 890000.0, 'S', 'Biggin', '17/09/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 150.0, 73.0, 1985.0, 'Yarra', -37.8011, 145.0004, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (20, 'Abbotsford', '3/72 Charles St', 4, 'h', 1330000.0, 'PI', 'Kay', '18/03/2017', 2.5, 3067.0, 4.0, 2.0, 2.0, 780.0, 135.0, 1900.0, 'Yarra', -37.8073, 144.9952, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (21, 'Abbotsford', '13/11 Nicholson St', 3, 't', 900000.0, 'S', 'Beller', '18/03/2017', 2.5, 3067.0, 3.0, 2.0, 2.0, 0.0, None, 2010.0, 'Yarra', -37.8093, 144.9959, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (22, 'Abbotsford', '138/56 Nicholson St', 3, 'u', 1090000.0, 'S', 'Jellis', '18/03/2017', 2.5, 3067.0, 3.0, 2.0, 2.0, 4290.0, 27.0, None, 'Yarra', -37.8078, 144.9965, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (23, 'Abbotsford', '6/219 Nicholson St', 2, 'u', 500000.0, 'S', 'Collins', '18/06/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 0.0, 60.0, 1970.0, 'Yarra', -37.8015, 144.9972, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (24, 'Abbotsford', '52a William St', 2, 'h', 1100000.0, 'PI', 'Biggin', '18/06/2016', 2.5, 3067.0, 2.0, 2.0, 1.0, 124.0, 135.0, 2013.0, 'Yarra', -37.8079, 144.9977, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (25, 'Abbotsford', '49 Park St', 2, 'h', 1315000.0, 'S', 'Marshall', '19/11/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 147.0, 85.0, 1900.0, 'Yarra', -37.808, 144.994, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (26, 'Abbotsford', '5/20 Abbotsford St', 1, 'u', 426000.0, 'SP', 'Greg', '22/08/2016', 2.5, 3067.0, 1.0, 1.0, 1.0, 0.0, None, None, 'Yarra', -37.8016, 144.9988, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (27, 'Abbotsford', '48 Abbotsford St', 3, 'h', 1447500.0, 'PI', 'Nelson', '22/08/2016', 2.5, 3067.0, 3.0, 3.0, 1.0, 166.0, 174.0, 2012.0, 'Yarra', -37.8017, 145.0001, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (28, 'Abbotsford', '116/56 Nicholson St', 1, 'u', 457000.0, 'S', 'Jellis', '22/08/2016', 2.5, 3067.0, 1.0, 1.0, 1.0, 0.0, 50.0, None, 'Yarra', -37.8078, 144.9965, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (29, 'Abbotsford', '159 Park St', 2, 'h', 1135000.0, 'S', 'Nelson', '22/08/2016', 2.5, 3067.0, 2.0, 2.0, 2.0, 98.0, 128.0, 1920.0, 'Yarra', -37.8005, 144.9952, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (30, 'Abbotsford', '31 Turner St', 4, 'h', 1542000.0, 'S', 'Collins', '24/09/2016', 2.5, 3067.0, 4.0, 3.0, 1.0, 0.0, None, None, 'Yarra', -37.7994, 144.9965, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (31, 'Abbotsford', '166 Gipps St', 3, 'h', 1290000.0, 'S', 'Biggin', '25/02/2017', 2.5, 3067.0, 3.0, 2.0, 2.0, 147.0, 18.0, None, 'Yarra', -37.805, 144.9943, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (32, 'Abbotsford', '60 Stafford St', 3, 'h', 1290000.0, 'S', 'Biggin', '25/02/2017', 2.5, 3067.0, 3.0, 1.0, 1.0, 168.0, 124.0, 1950.0, 'Yarra', -37.8007, 144.9958, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (33, 'Abbotsford', '11/205 Gipps St', 1, 'u', 470000.0, 'S', 'Nelson', '26/07/2016', 2.5, 3067.0, 1.0, 1.0, 1.0, 0.0, 50.0, 2013.0, 'Yarra', -37.8055, 144.9961, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (34, 'Abbotsford', '47 Studley St', 2, 'h', 1180000.0, 'S', 'Jellis', '27/11/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 162.0, 91.0, 1900.0, 'Yarra', -37.8016, 144.9956, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (35, 'Abbotsford', '45 Yarra St', 3, 'h', 1195000.0, 'SP', 'Jellis', '27/11/2016', 2.5, 3067.0, 3.0, 2.0, 1.0, 120.0, 128.0, 1998.0, 'Yarra', -37.8022, 144.9954, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (36, 'Abbotsford', '200 Nicholson St', 2, 'h', 1012500.0, 'S', 'Nelson', '28/05/2016', 2.5, 3067.0, 2.0, 1.0, 0.0, 182.0, 82.0, 1900.0, 'Yarra', -37.8021, 144.9976, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (37, 'Abbotsford', '27 Charles St', 2, 'h', 1030000.0, 'S', 'Biggin', '30/07/2016', 2.5, 3067.0, 2.0, 1.0, 1.0, 172.0, 81.0, 1930.0, 'Yarra', -37.8086, 144.9946, 'Northern Metropolitan', 4019.0, ' - ', 3067, 258, 130.62403100775194, 605.1521739130435, 2187.032258064516)
# (38, 'Airport West', '154 Halsey Rd', 3, 't', 840000.0, 'PI', 'Nelson', '3/09/2016', 13.5, 3042.0, 3.0, 2.0, 1.0, 303.0, 225.0, 2016.0, 'Moonee Valley', -37.718, 144.878, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (39, 'Airport West', '50 Bedford St', 3, 'h', 730000.0, 'VB', 'Nelson', '3/12/2016', 13.5, 3042.0, 3.0, 2.0, 1.0, 0.0, 145.0, 1965.0, 'Moonee Valley', -37.7203, 144.8755, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (40, 'Airport West', '50 Bedford St', 3, 'h', 770000.0, 'SP', 'Nelson', '4/03/2017', 13.5, 3042.0, 3.0, 2.0, 1.0, 0.0, 145.0, 1965.0, 'Moonee Valley', -37.7203, 144.8755, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (41, 'Airport West', '23 Hart St', 2, 'h', 603000.0, 'S', 'Nelson', '4/03/2017', 13.5, 3042.0, 2.0, 1.0, 1.0, 272.0, 84.0, 1950.0, 'Moonee Valley', -37.7294, 144.888, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (42, 'Airport West', '1/80 Hawker St', 3, 't', 700000.0, 'S', 'Brad', '4/03/2017', 13.5, 3042.0, 3.0, 2.0, 2.0, 239.0, 134.0, 2009.0, 'Moonee Valley', -37.7218, 144.8837, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (43, 'Airport West', '1/37 Hillside Gr', 3, 'h', 600000.0, 'S', 'Maddison', '4/03/2017', 13.5, 3042.0, 2.0, 1.0, 1.0, 290.0, 116.0, 1980.0, 'Moonee Valley', -37.7273, 144.8744, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (44, 'Airport West', '2/49 McIntosh St', 2, 'u', 500000.0, 'VB', 'Barry', '4/03/2017', 13.5, 3042.0, 2.0, 1.0, 1.0, 168.0, 86.0, 2011.0, 'Moonee Valley', -37.7215, 144.8864, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (45, 'Airport West', '54 Marshall Rd', 3, 'h', 720000.0, 'S', 'Barry', '6/08/2016', 13.5, 3042.0, 2.0, 1.0, 1.0, 620.0, None, None, 'Moonee Valley', -37.7173, 144.8872, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (46, 'Airport West', '36 Roberts Rd', 4, 'h', 785000.0, 'S', 'Considine', '6/08/2016', 13.5, 3042.0, 3.0, 1.0, 2.0, 597.0, 127.0, None, 'Moonee Valley', -37.7259, 144.8792, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (47, 'Airport West', '11 Harrington Rd', 6, 'h', 725000.0, 'SP', 'Barry', '7/05/2016', 13.5, 3042.0, 6.0, 3.0, 2.0, 976.0, 186.0, 1980.0, 'Moonee Valley', -37.7239, 144.8735, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (48, 'Airport West', '2/252 Parer Rd', 2, 't', 450000.0, 'S', 'Barry', '7/05/2016', 13.5, 3042.0, 2.0, 1.0, 1.0, 110.0, 90.0, 2015.0, 'Moonee Valley', -37.7216, 144.871, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (49, 'Airport West', '3/19 Hart St', 2, 'u', 515000.0, 'S', 'Barry', '7/11/2016', 13.5, 3042.0, 2.0, 1.0, 1.0, 141.0, 73.0, 2013.0, 'Moonee Valley', -37.7298, 144.8883, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (50, 'Airport West', '2/62 Clydesdale Rd', 2, 'u', 530000.0, 'S', 'Nelson', '10/09/2016', 13.5, 3042.0, 2.0, 1.0, 1.0, 120.0, 94.0, 2012.0, 'Moonee Valley', -37.7234, 144.8792, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (51, 'Airport West', '3 Deidre Ct', 3, 'h', 895000.0, 'PI', 'Rendina', '10/09/2016', 13.5, 3042.0, 3.0, 1.0, 6.0, 1063.0, 133.0, 1975.0, 'Moonee Valley', -37.7249, 144.8728, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (52, 'Airport West', '13 Etzel St', 3, 'h', 805000.0, 'S', 'Nelson', '10/12/2016', 13.5, 3042.0, 3.0, 1.0, 1.0, 0.0, 105.0, 1950.0, 'Moonee Valley', -37.7217, 144.8783, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (53, 'Airport West', '1/43 Cameron St', 3, 'u', 752000.0, 'S', 'Nelson', '11/02/2017', 13.5, 3042.0, 3.0, 1.0, 1.0, 265.0, 130.0, 1993.0, 'Moonee Valley', -37.7302, 144.8855, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (54, 'Airport West', '145a Victory Rd', 2, 'u', 440000.0, 'S', 'Barry', '13/08/2016', 13.5, 3042.0, 2.0, 1.0, 1.0, 192.0, None, None, 'Moonee Valley', -37.7177, 144.8787, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (55, 'Airport West', '241 Parer Rd', 5, 'h', 755000.0, 'PI', 'Propertyau', '14/05/2016', 13.5, 3042.0, 3.0, 2.0, 2.0, 596.0, None, None, 'Moonee Valley', -37.7248, 144.8699, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (56, 'Airport West', '2/40 Earl St', 3, 't', 700000.0, 'PI', 'Brad', '15/10/2016', 13.5, 3042.0, 3.0, 2.0, 2.0, 165.0, 133.0, 2009.0, 'Moonee Valley', -37.727, 144.887, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (57, 'Airport West', '180 Parer Rd', 3, 'h', 830000.0, 'S', 'Barry', '16/04/2016', 13.5, 3042.0, 3.0, 1.0, 2.0, 971.0, 113.0, 1960.0, 'Moonee Valley', -37.7186, 144.876, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (58, 'Airport West', '4/54 Hawker St', 2, 'u', 462500.0, 'S', 'Barry', '16/07/2016', 13.5, 3042.0, 2.0, 1.0, 1.0, 164.0, None, 2003.0, 'Moonee Valley', -37.7218, 144.8863, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (59, 'Airport West', '43 Hillside Gr', 3, 'h', 670000.0, 'SP', 'Barry', '16/07/2016', 13.5, 3042.0, 3.0, 2.0, 2.0, 657.0, None, None, 'Moonee Valley', -37.7269, 144.8742, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (60, 'Airport West', '174 Parer Rd', 2, 'h', 675000.0, 'S', 'Barry', '16/07/2016', 13.5, 3042.0, 2.0, 1.0, 1.0, 612.0, 100.0, 1975.0, 'Moonee Valley', -37.7187, 144.8765, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (61, 'Airport West', '138 Victory Rd', 3, 'h', 1042000.0, 'S', 'Nelson', '16/07/2016', 13.5, 3042.0, 3.0, 2.0, 5.0, 612.0, 174.0, 1950.0, 'Moonee Valley', -37.7173, 144.8796, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (62, 'Airport West', '75 King St', 3, 'h', 910000.0, 'S', 'McDonald', '17/09/2016', 13.5, 3042.0, 3.0, 1.0, 1.0, 775.0, None, None, 'Moonee Valley', -37.7231, 144.8835, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (63, 'Airport West', '6 Kittyhawk St', 4, 'h', 773000.0, 'S', 'Brad', '17/09/2016', 13.5, 3042.0, 5.0, 3.0, 4.0, 531.0, 309.0, 1980.0, 'Moonee Valley', -37.7263, 144.8679, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (64, 'Airport West', '478 Fullarton Rd', 3, 'h', 810000.0, 'PI', 'Barry', '18/03/2017', 13.5, 3042.0, 3.0, 3.0, 2.0, 555.0, 192.0, 1980.0, 'Moonee Valley', -37.7285, 144.8694, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (65, 'Airport West', '144 Marshall Rd', 3, 'h', 715000.0, 'S', 'Rendina', '18/03/2017', 13.5, 3042.0, 3.0, 2.0, 2.0, 422.0, 126.0, 1995.0, 'Moonee Valley', -37.7164, 144.8792, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (66, 'Airport West', '106 Parer Rd', 3, 'h', 790000.0, 'S', 'Nelson', '18/03/2017', 13.5, 3042.0, 3.0, 1.0, 3.0, 614.0, None, None, 'Moonee Valley', -37.7194, 144.8827, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (67, 'Airport West', '3/7 South Rd', 3, 't', 540000.0, 'SP', 'Nelson', '18/06/2016', 13.5, 3042.0, 2.0, 2.0, 1.0, 161.0, 101.0, 2010.0, 'Moonee Valley', -37.7231, 144.8802, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (68, 'Airport West', '37 North St', 3, 't', 825000.0, 'SP', 'Barry', '19/11/2016', 13.5, 3042.0, 3.0, 2.0, 1.0, 293.0, 102.0, 1960.0, 'Moonee Valley', -37.72, 144.8776, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (69, 'Airport West', '10 Hilbert Rd', 3, 'h', 685000.0, 'S', 'Barry', '22/05/2016', 13.5, 3042.0, 3.0, 1.0, 1.0, 579.0, 113.0, 1975.0, 'Moonee Valley', -37.7226, 144.8733, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (70, 'Airport West', '110 Halsey Rd', 3, 'h', 805000.0, 'S', 'Barry', '22/08/2016', 13.5, 3042.0, 3.0, 1.0, 1.0, 623.0, None, None, 'Moonee Valley', -37.7184, 144.882, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (71, 'Airport West', '2/13 North St', 2, 'u', 510000.0, 'S', 'Nelson', '22/08/2016', 13.5, 3042.0, 2.0, 1.0, 1.0, 141.0, 76.0, None, 'Moonee Valley', -37.7202, 144.8797, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (72, 'Airport West', '105a Victory Rd', 3, 'h', 612000.0, 'S', 'Nelson', '22/08/2016', 13.5, 3042.0, 3.0, 2.0, 1.0, 212.0, None, None, 'Moonee Valley', -37.7181, 144.8824, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (73, 'Airport West', '117 Marshall Rd', 3, 'h', 662000.0, 'S', 'Brad', '23/04/2016', 13.5, 3042.0, 3.0, 1.0, 2.0, 612.0, None, None, 'Moonee Valley', -37.7169, 144.8815, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (74, 'Airport West', '34 Moorna Dr', 4, 'h', 978000.0, 'S', 'Nelson', '24/09/2016', 13.5, 3042.0, 4.0, 3.0, 2.0, 532.0, None, None, 'Moonee Valley', -37.7263, 144.869, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (75, 'Airport West', '33 North St', 3, 'h', 720000.0, 'PI', 'Nelson', '25/02/2017', 13.5, 3042.0, 3.0, 1.0, 1.0, 585.0, None, None, 'Moonee Valley', -37.72, 144.878, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (76, 'Airport West', '49 Roberts Rd', 4, 'h', 765000.0, 'S', 'Prof.', '27/11/2016', 13.5, 3042.0, 4.0, 1.0, 2.0, 509.0, None, None, 'Moonee Valley', -37.7261, 144.8785, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (77, 'Airport West', '85 Roberts Rd', 4, 'h', 900000.0, 'S', 'Harcourts', '27/11/2016', 13.5, 3042.0, 4.0, 2.0, 3.0, 628.0, 146.0, 1975.0, 'Moonee Valley', -37.7256, 144.8739, 'Western Metropolitan', 3464.0, ' - ', 3042, 35, 81.57142857142857, 568.2, 1800.75)
# (78, 'Albert Park', '105 Kerferd Rd', 2, 'h', 1275000.0, 'S', 'hockingstuart', '3/09/2016', 3.3, 3206.0, 2.0, 1.0, 0.0, 120.0, 82.0, 1900.0, 'Port Phillip', -37.8459, 144.9555, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (79, 'Albert Park', '85 Richardson St', 2, 'h', 1455000.0, 'S', 'Thomson', '3/09/2016', 3.3, 3206.0, 2.0, 1.0, 0.0, 159.0, None, None, 'Port Phillip', -37.845, 144.9538, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (80, 'Albert Park', '112 Beaconsfield Pde', 3, 'h', 2850000.0, 'PI', 'Buxton', '4/03/2017', 3.3, 3206.0, 3.0, 2.0, 0.0, 211.0, 198.0, 1890.0, 'Port Phillip', -37.8481, 144.9499, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (81, 'Albert Park', '94 Graham St', 3, 'h', 1850000.0, 'S', 'Greg', '4/03/2017', 3.3, 3206.0, 3.0, 2.0, 0.0, 128.0, 133.0, 1890.0, 'Port Phillip', -37.8452, 144.9488, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (82, 'Albert Park', '396 Montague St', 2, 'h', 1436000.0, 'S', 'RT', '4/03/2017', 3.3, 3206.0, 2.0, 1.0, 0.0, 130.0, 81.0, 1900.0, 'Port Phillip', -37.8431, 144.9565, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (83, 'Albert Park', '75 Graham St', 2, 'h', 1110000.0, 'S', 'Marshall', '6/08/2016', 3.3, 3206.0, 1.0, 1.0, 0.0, 147.0, None, 1900.0, 'Port Phillip', -37.8444, 144.9484, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (84, 'Albert Park', '54 Brooke St', 2, 'h', 1550000.0, 'S', "Sotheby's", '7/05/2016', 3.3, 3206.0, 2.0, 1.0, 1.0, 167.0, None, None, 'Port Phillip', -37.8405, 144.9521, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (85, 'Albert Park', '104 Richardson St', 4, 'h', 2300000.0, 'S', 'Marshall', '7/05/2016', 3.3, 3206.0, 4.0, 2.0, 1.0, 153.0, 180.0, 1880.0, 'Port Phillip', -37.8447, 144.9523, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (86, 'Albert Park', '4a Mills St', 3, 't', 1550000.0, 'VB', 'Marshall', '7/11/2016', 3.3, 3206.0, 3.0, 2.0, 2.0, 718.0, None, None, 'Port Phillip', -37.8443, 144.9598, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (87, 'Albert Park', '1 Moubray St', 3, 'h', 1800000.0, 'VB', 'Greg', '7/11/2016', 3.3, 3206.0, 3.0, 2.0, 1.0, 132.0, 159.0, 1996.0, 'Port Phillip', -37.8415, 144.952, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (88, 'Albert Park', '29 Faussett St', 2, 'h', 2120000.0, 'S', 'Greg', '10/09/2016', 3.3, 3206.0, 2.0, 1.0, 1.0, 199.0, 107.0, 1900.0, 'Port Phillip', -37.8422, 144.9554, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (89, 'Albert Park', '3 Herbert St', 3, 'h', 1800000.0, 'VB', 'Cayzer', '10/09/2016', 3.3, 3206.0, 3.0, 1.0, 1.0, 253.0, None, None, 'Port Phillip', -37.8443, 144.9579, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (90, 'Albert Park', '24 Kerferd Pl', 3, 'h', 1800000.0, 'S', 'Marshall', '10/09/2016', 3.3, 3206.0, 3.0, 2.0, 1.0, 90.0, 122.0, 1900.0, 'Port Phillip', -37.8421, 144.9571, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (91, 'Albert Park', '44 Draper St', 2, 'h', 1810000.0, 'PI', 'Greg', '10/12/2016', 3.3, 3206.0, 2.0, 1.0, 0.0, 240.0, None, None, 'Port Phillip', -37.8379, 144.9539, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (92, 'Albert Park', '2 Dundas Pl', 3, 'h', 2615000.0, 'S', 'Cayzer', '10/12/2016', 3.3, 3206.0, 3.0, 2.0, 1.0, 177.0, 181.0, 1880.0, 'Port Phillip', -37.8415, 144.9585, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (93, 'Albert Park', '23 Finlay St', 5, 'h', 2100000.0, 'S', 'Greg', '10/12/2016', 3.3, 3206.0, 5.0, 2.0, 1.0, 237.0, None, None, 'Port Phillip', -37.8436, 144.9557, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (94, 'Albert Park', '31 Richardson St', 3, 'h', 1300000.0, 'S', 'hockingstuart', '10/12/2016', 3.3, 3206.0, 3.0, 1.0, 0.0, 129.0, None, None, 'Port Phillip', -37.8422, 144.94899999999996, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (95, 'Albert Park', '4a Gatehouse La', 3, 'h', 1370000.0, 'S', 'Greg', '12/06/2016', 3.3, 3206.0, 3.0, 2.0, 2.0, 0.0, 85.0, 2000.0, 'Port Phillip', -37.8451, 144.9511, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (96, 'Albert Park', '60 Brooke St', 2, 'h', 1000000.0, 'S', 'Cayzer', '12/11/2016', 3.3, 3206.0, 2.0, 1.0, 0.0, 288.0, None, None, 'Port Phillip', -37.8407, 144.9523, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (97, 'Albert Park', '70 Barrett St', 3, 'h', 2575000.0, 'S', 'Greg', '15/10/2016', 3.3, 3206.0, 3.0, 2.0, 1.0, 228.0, None, None, 'Port Phillip', -37.8445, 144.9501, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (98, 'Albert Park', '65 Graham St', 2, 'h', 1322500.0, 'S', 'Greg', '15/10/2016', 3.3, 3206.0, 2.0, 1.0, 0.0, 149.0, 98.0, 1890.0, 'Port Phillip', -37.8443, 144.9481, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)
# (99, 'Albert Park', '364 Montague St', 2, 'h', 1562500.0, 'S', 'Greg', '15/10/2016', 3.3, 3206.0, 2.0, 1.0, 0.0, 141.0, 83.0, 1890.0, 'Port Phillip', -37.8424, 144.9562, 'Southern Metropolitan', 3280.0, ' - ', 3206, 122, 229.41803278688525, 1187.4, 3734.0)

# %% [markdown]
# ## Ejercicio 2:
#
# 1. Seleccionar un subconjunto de columnas que les parezcan relevantes al problema de predicción del valor de la propiedad. Justificar las columnas seleccionadas y las que no lo fueron.
#  - Eliminar los valores extremos que no sean relevantes para la predicción de valores de las propiedades.
#
# 2. Agregar información adicional respectiva al entorno de una propiedad a partir del [conjunto de datos de AirBnB](https://www.kaggle.com/tylerx/melbourne-airbnb-open-data?select=cleansed_listings_dec18.csv) utilizado en el práctico.
#   1. Seleccionar qué variables agregar y qué combinaciones aplicar a cada una. Por ejemplo, pueden utilizar solo la columna `price`, o aplicar múltiples transformaciones como la mediana o el mínimo.
#   1. Utilizar la variable zipcode para unir los conjuntos de datos. Sólo incluir los zipcodes que tengan una cantidad mínima de registros (a elección) como para que la información agregada sea relevante.
#   2. Investigar al menos otras 2 variables que puedan servir para combinar los datos, y justificar si serían adecuadas o no. Pueden asumir que cuentan con la ayuda de anotadores expertos para encontrar equivalencias entre barrios o direcciones, o que cuentan con algoritmos para encontrar las n ubicaciones más cercanas a una propiedad a partir de sus coordenadas geográficas. **NO** es necesario que realicen la implementación.
#
# Pueden leer otras columnas del conjunto de AirBnB además de las que están en `interesting_cols`, si les parecen relevantes.

# %% [markdown]
# ### **Ejercicio 2.1**

# %%
import pandas 
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

# Selección de las columnas/campos más relevantes para determinar el precio de venta:
# Creación de un nuevo DF con la información de Ventas de Melbourne
url = 'https://drive.google.com/file/d/1TTNArP_0BV23Lw-UzDv_bPtf5vmhOQbB/view?usp=sharing'
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
ventas_melbourne_df = pandas.read_csv(path)

# ventas_melbourne_df.dtypes

ventas_melbourne_df.describe()
msno.matrix(ventas_melbourne_df)

# BuildingArea y YearBuilt tienen muchos valores faltantes.

# %% [markdown]
# ### **Elección de los Variables Relevantes**

# %% [markdown]
# Como primera medida se tratan de diferente manera las variables categóricas de las variables numéricas:

# %%
ventas_melbourne_df.dtypes.sort_values(ascending=False)
# Out:
# Suburb            object
# Regionname        object
# Type              object
# Method            object
# SellerG           object
# Date              object
# CouncilArea       object
# Address           object
# Landsize         float64
# Longtitude       float64
# Lattitude        float64
# YearBuilt        float64
# BuildingArea     float64
# Bedroom2         float64
# Car              float64
# Bathroom         float64
# Postcode         float64
# Distance         float64
# Price            float64
# Propertycount    float64
# Rooms              int64
# dtype: object

# %% [markdown]
# ### Variables Categóricas:

# %%
categories = ventas_melbourne_df.columns[ventas_melbourne_df.dtypes == 'object']

for category in categories:
  print(f'Variable: {category}')
  print(f'Cantidad de valores únicos: {len(ventas_melbourne_df[category].unique())}')
  print(f'Primeros valores: \n{ventas_melbourne_df[category].value_counts().head()}\n')


  #plt.figure(figsize = (20,8))
  #sns.histplot(data=ventas_melbourne_df, x="Price", hue="Method")
# Out:
# Variable: Suburb
# Cantidad de valores únicos: 311
# Primeros valores:
# Reservoir         351
# Richmond          260
# Bentleigh East    242
# Preston           231
# Essendon          218
# Name: Suburb, dtype: int64
#
# Variable: Address
# Cantidad de valores únicos: 13066
# Primeros valores:
# 5 Charles St     3
# 14 Arthur St     3
# 53 William St    3
# 5 Margaret St    3
# 2 Bruce St       3
# Name: Address, dtype: int64
#
# Variable: Type
# Cantidad de valores únicos: 3
# Primeros valores:
# h    9163
# u    3005
# t    1095
# Name: Type, dtype: int64
#
# Variable: Method
# Cantidad de valores únicos: 5
# Primeros valores:
# S     8809
# SP    1667
# PI    1534
# VB    1161
# SA      92
# Name: Method, dtype: int64
#
# Variable: SellerG
# Cantidad de valores únicos: 266
# Primeros valores:
# Nelson           1538
# Jellis           1282
# hockingstuart    1148
# Barry             991
# Ray               672
# Name: SellerG, dtype: int64
#
# Variable: Date
# Cantidad de valores únicos: 58
# Primeros valores:
# 27/05/2017    473
# 3/06/2017     395
# 12/08/2017    387
# 17/06/2017    374
# 27/11/2016    362
# Name: Date, dtype: int64
#
# Variable: CouncilArea
# Cantidad de valores únicos: 33
# Primeros valores:
# Melbourne        1522
# Moreland         1163
# Boroondara       1160
# Moonee Valley     997
# Darebin           934
# Name: CouncilArea, dtype: int64
#
# Variable: Regionname
# Cantidad de valores únicos: 8
# Primeros valores:
# Southern Metropolitan         4579
# Northern Metropolitan         3812
# Western Metropolitan          2898
# Eastern Metropolitan          1433
# South-Eastern Metropolitan     421
# Name: Regionname, dtype: int64

# %% [markdown]
# En la selección de variables categóricas, al no tener mayores precisiones sobre qué información puede ser relevante o no, comenzamos por eliminar la que entendemos que no aporta mucho valor y que podemos descartar sin riesgo.
#
# Así, se eliminan las variables:
#
# *   *Address*: Por tratarse de un valor prácticamente único para cada venta. No permite generalizar para sacar algún dato importante.
# *   *Regionname*: Teniendo información geográfica importante con las variables *CouncilArea* y *Suburb*, la region resulta innecesaria.
# *   *Date*: La fecha tampoco aporta mucho valor al estudio, ya que son ventas que abarcan sólo los años 2016 y 2017, por lo que no nos permite ver una tendencia a mediana largo plazo.
# *   *SellerG*: Finalmente, el vendedor, entendemos, resulta una variable poco relevante para el estudio.

# %%
#Borrado de las variables descartadas
drop_columns=['Address','Regionname','Date','SellerG']
ventas_melbourne_df.drop(drop_columns, axis=1, inplace=True)

categories = ventas_melbourne_df.columns[ventas_melbourne_df.dtypes == 'object']
categories
# Out:
# Index(['Suburb', 'Type', 'Method', 'CouncilArea'], dtype='object')

# %% [markdown]
# **Variables Categóricas Seleccionadas:**
# Tenemos en definitiva dos variables categóricas geográficas, el partido (CouncilArea) y el barrio (Suburb) y por otro lado dos variables con pocas categorías que indican el tipo de propiedad vendida (Type) y el tipo de operación realizada (Method).

# %% [markdown]
# ### Variables Numéricas:

# %%
numericals = ventas_melbourne_df.columns[(ventas_melbourne_df.dtypes == 'int64') | (ventas_melbourne_df.dtypes == 'float64')]
numericals
# Out:
# Index(['Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'Lattitude', 'Longtitude',
#        'Propertycount'],
#       dtype='object')

# %% [markdown]
# **Correlación de las variables numéricas**

# %%
#Correlación
import seaborn as sns
import numpy as np

df_corr = ventas_melbourne_df[numericals]

corrmat = df_corr.corr()
k = len(df_corr.columns) #number of variables for heatmap
f, ax = plt.subplots(figsize=(15, 10))
cols = corrmat.nlargest(k, 'Price')['Price'].index
cm = np.corrcoef(df_corr[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 9}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# El mapa de calor de las variables numéricas realmente no muestra ninguna variable con un indice de correlación alto.
#
# En consecuencia graficaremos todas las variables numéricas vs la variable objetivo para explorar las distribuciones en un scatterplot.
#
# **Nota**: Las variables BuildingArea, Car y YearBuilt tienen registros NaN, a eso se debe que el mapa de calor de correlación no muestre resultados. Exploraremos estas variables individualmente más abajo.

# %%
fig = plt.figure(figsize=(22, 16))
fig.subplots_adjust(hspace=0.2, wspace=0.2)
colors = plt.get_cmap('tab20').colors

for id, feature, color in zip(range(len(numericals)),numericals,colors):
    mtx = fig.add_subplot(4, 4, id+1)
    mtx.title.set_text(feature)
    mtx.scatter(ventas_melbourne_df[feature], ventas_melbourne_df.Price, color=color)

# %% [markdown]
# Con el mismo criterio anterior, empezaremos descartando las variables que entendemos no aportan información relevante.
#
# *   *Lattitude* y *Longtitude*: Al igual que la dirección, es información geográfica que ya utilizamos para completar los datos faltantes de la variable CouncilArea.
# *   *PostCode*: Si bien no aporta mucha información, sirve para complementar el dataset con datos provenientes de la base de datos de AirBnb
# *   *Propertycount*: A un nivel superficial, no se que haya algún tipo de correlación u orientación con el precio, por lo que se descarta la variable.

# %%
#Borrado de las variables descartadas
drop_columns=['Longtitude','Lattitude','Propertycount']
ventas_melbourne_df.drop(drop_columns, axis=1, inplace=True)

numericals = ventas_melbourne_df.columns[(ventas_melbourne_df.dtypes == 'int64') | (ventas_melbourne_df.dtypes == 'float64')]
# Ni el precio ni el código postal se pueden descartar, pero tampoco hacen falta ahora para este gráfico
numericals = numericals.drop(['Price','Postcode'])
numericals
# Out:
# Index(['Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'YearBuilt'],
#       dtype='object')

# %% [markdown]
# Imprimimos nuevamente los ScatterPlot para visualizar mejor:

# %%
fig = plt.figure(figsize=(22, 16))
fig.subplots_adjust(hspace=0.2, wspace=0.2)
colors = plt.get_cmap('tab20').colors

for id, feature, color in zip(range(len(numericals)),numericals,colors):
    mtx = fig.add_subplot(4, 4, id+1)
    mtx.title.set_text(feature)
    mtx.scatter(ventas_melbourne_df[feature], ventas_melbourne_df.Price, color=color)

# %% [markdown]
# ### Limpieza de Outliers

# %% [markdown]
# Antes de terminar la selección de las variables numéricas, eliminaremos los outliers para las variables *Bedroom2*, *Landsize*, *BuildingArea* y *YearBuilt* que, como puede verse en las gráficas, no dejan visualizar si hay alguna tendencia en las observaciones:
#
# **Bedroom2**:

# %%
ventas_melbourne_df['Bedroom2'].sort_values()
# Out:
# 804       0.0
# 7385      0.0
# 8300      0.0
# 3360      0.0
# 6170      0.0
#          ...
# 6915      9.0
# 379       9.0
# 4980      9.0
# 11302    10.0
# 7404     20.0
# Name: Bedroom2, Length: 13263, dtype: float64

# %%
ventas_melbourne_df = ventas_melbourne_df[ventas_melbourne_df['Bedroom2'] < 20]

# %% [markdown]
# **Landsize**:

# %%
ventas_melbourne_df['Landsize'].sort_values()
# Out:
# 7810          0.0
# 7449          0.0
# 6841          0.0
# 6840          0.0
# 10249         0.0
#            ...
# 11369     40468.0
# 5194      41400.0
# 687       75100.0
# 10503     76000.0
# 11018    433014.0
# Name: Landsize, Length: 13262, dtype: float64

# %% [markdown]
# Esta variable muestra valores muy altos por un lado y una gran concentración de valores en 0. Intuitivamente antes de eliminar registros veremos qué pasa con esta variable versus la variable *Type*:

# %%
ventas_melbourne_df = ventas_melbourne_df.drop(ventas_melbourne_df[ventas_melbourne_df['Landsize'] > 5000].index)

# %% [markdown]
# **YearBuilt**:

# %%
ventas_melbourne_df['YearBuilt'].sort_values()
# Out:
# 9967     1196.0
# 2079     1830.0
# 4843     1850.0
# 5860     1850.0
# 2554     1850.0
#           ...
# 13249       NaN
# 13250       NaN
# 13252       NaN
# 13253       NaN
# 13257       NaN
# Name: YearBuilt, Length: 13203, dtype: float64

# %%
ventas_melbourne_df = ventas_melbourne_df.drop(ventas_melbourne_df[ventas_melbourne_df['YearBuilt'] < 1800].index)

# %% [markdown]
# **BuildingArea**:

# %%
ventas_melbourne_df['BuildingArea'].sort_values()
# Out:
# 12240    0.0
# 4344     0.0
# 12977    0.0
# 13174    0.0
# 13213    0.0
#         ...
# 13252    NaN
# 13253    NaN
# 13257    NaN
# 13258    NaN
# 13260    NaN
# Name: BuildingArea, Length: 13202, dtype: float64

# %%
ventas_melbourne_df = ventas_melbourne_df.drop(ventas_melbourne_df[ventas_melbourne_df['BuildingArea'] > 2000].index)

# %% [markdown]
# Imprimos nuevamente los gráficos individualmente para elegir qué variables conservaremos en el dataset.

# %%
fig = plt.figure(figsize=(22, 16))
fig.subplots_adjust(hspace=0.2, wspace=0.2)
colors = plt.get_cmap('tab20').colors

for id, feature, color in zip(range(len(numericals)),numericals,colors):
    mtx = fig.add_subplot(4, 4, id+1)
    mtx.title.set_text(feature)
    mtx.scatter(ventas_melbourne_df[feature], ventas_melbourne_df.Price, color=color)

# %% [markdown]
# Las variables *Rooms* y *Bedroom2* tienen un comportamiento muy similar y tienen un índice de correlación de 0.91 (ver heatmap arriba). Por lo que optamos por quedarnos con *Rooms* que tiene mayor correlación con el precio.
#
# Finalmente, y siguiendo el mismo criterio, se descartan las variables Car y Bathrooms.

# %%
#Borrado de las variables descartadas
drop_columns=['Bedroom2','Bathroom','Car']
ventas_melbourne_df.drop(drop_columns, axis=1, inplace=True)

numericals = ventas_melbourne_df.columns[ventas_melbourne_df.dtypes.isin(['int64','float64'])]
numericals
# Out:
# Index(['Rooms'], dtype='object')

# %% [markdown]
# ### **Ejercicio 2.2**

# %% [markdown]
# Preparamos el dataset de AirBnb, agrupando los datos por la variable zipcode

# %%
# Agrupamiento de los zipcodes y cálculo de principales métricas
zipcodes_df = airbnb_df.groupby(['zipcode']).agg({'price':['count','median','mean','std']}).price.reset_index()

# Eliminamos los valores con menos de 10 muestras
zipcodes_df.drop(zipcodes_df[zipcodes_df['count'] < 10].index, inplace=True)

# Renombro las nuevas variables
zipcodes_df.columns = ['zipcode', 'Airbnb_Qtty', 'Airbnb_Median', 'Airbnb_Mean', 'Airbnb_DevStd']

zipcodes_df.sort_values('Airbnb_Qtty', ascending=False)
# Out:
#      zipcode  Airbnb_Qtty  Airbnb_Median  Airbnb_Mean  Airbnb_DevStd
# 3     3000.0         3367          129.0   150.504307     189.529766
# 8     3006.0         1268          150.0   188.851735     196.919689
# 154   3182.0         1135          118.0   147.729515     150.590741
# 116   3141.0          881          120.0   157.912599     238.634459
# 7     3004.0          728          130.0   158.271978     131.771854
# ..       ...          ...            ...          ...            ...
# 152   3180.0           10           67.5   282.500000     605.930552
# 64    3075.0           10          157.0   142.800000      86.302826
# 91    3111.0           10          119.0   151.800000     116.305918
# 228   3911.0           10          225.0   334.600000     341.080701
# 81    3099.0           10          120.0   136.000000      67.275553
#
# [182 rows x 5 columns]

# %% [markdown]
# Hacemos el merge de los dos datasets

# %%
# Left merge final, agregando al DF de Melbourne los datos de AirBnb
final_df = pandas.merge(ventas_melbourne_df, zipcodes_df, how='left', left_on=['Postcode'], right_on=['zipcode'])

# Eliminamos el zipcode duplicado
final_df.drop('zipcode', axis=1, inplace=True)

final_df
# Out:
#               Suburb  Rooms Type      Price Method  Distance  Postcode  \
# 0         Abbotsford      2    h  1480000.0      S       2.5    3067.0
# 1         Abbotsford      2    h  1035000.0      S       2.5    3067.0
# 2         Abbotsford      3    h  1465000.0     SP       2.5    3067.0
# 3         Abbotsford      3    h   850000.0     PI       2.5    3067.0
# 4         Abbotsford      4    h  1600000.0     VB       2.5    3067.0
# ...              ...    ...  ...        ...    ...       ...       ...
# 13194  Wheelers Hill      4    h  1245000.0      S      16.7    3150.0
# 13195   Williamstown      3    h  1031000.0     SP       6.8    3016.0
# 13196   Williamstown      3    h  1170000.0      S       6.8    3016.0
# 13197   Williamstown      4    h  2500000.0     PI       6.8    3016.0
# 13198     Yarraville      4    h  1285000.0     SP       6.3    3013.0
#
#        Landsize  BuildingArea  YearBuilt CouncilArea  Airbnb_Qtty  \
# 0         202.0           NaN        NaN       Yarra        258.0
# 1         156.0          79.0     1900.0       Yarra        258.0
# 2         134.0         150.0     1900.0       Yarra        258.0
# 3          94.0           NaN        NaN       Yarra        258.0
# 4         120.0         142.0     2014.0       Yarra        258.0
# ...         ...           ...        ...         ...          ...
# 13194     652.0           NaN     1981.0   Melbourne        189.0
# 13195     333.0         133.0     1995.0   Melbourne         74.0
# 13196     436.0           NaN     1997.0   Melbourne         74.0
# 13197     866.0         157.0     1920.0   Melbourne         74.0
# 13198     362.0         112.0     1920.0   Melbourne         82.0
#
#        Airbnb_Median  Airbnb_Mean  Airbnb_DevStd
# 0              100.0   130.624031     115.267487
# 1              100.0   130.624031     115.267487
# 2              100.0   130.624031     115.267487
# 3              100.0   130.624031     115.267487
# 4              100.0   130.624031     115.267487
# ...              ...          ...            ...
# 13194           80.0   124.026455     100.772518
# 13195          180.0   191.094595     128.556919
# 13196          180.0   191.094595     128.556919
# 13197          180.0   191.094595     128.556919
# 13198          108.5   135.609756      89.652795
#
# [13199 rows x 15 columns]

# %%
msno.matrix(final_df)

# %% [markdown]
# Se imprime finalmente la matrix de missing values, para ver cómo queda el dataframe.
#
# Se observa que hubo algunos zipcodes del dataset original de ventas en Melbourn para los cuales no se pudieron obtener datos de la base de AirBnb. Dejamos estas líneas de cualquier manera porque son datos complementarios.

# %% [markdown]
# ## Ejercicio 3:
#
# Crear y guardar un nuevo conjunto de datos con todas las transformaciones realizadas anteriormente.

# %%
# Generar un archivo .csv con el formato final 
final_df.to_csv('final_df.csv', index=None)
from google.colab import files
files.download('final_df.csv')
